# %% [markdown]
# # A notebook to pracitice Data Cleaning.

# %%
import pandas as pd

# %%
# %run BasicDataExploration.ipynb

# %% [markdown]
# ## Step 1 -- Load the Data

# %%
dataFrame = pd.read_csv('Uncleaned_DS_jobs.csv', index_col=0 )
dataFrame.head(2)
# Out:
#                Job Title               Salary Estimate
# index
# 0      Sr Data Scientist  $137K-$171K (Glassdoor est.)  \
# 1         Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                          Job Description  Rating
# index
# 0      Description\r\n\r\nThe Senior Data Scientist i...     3.1  \
# 1      Secure our Nation, Ignite your Future\r\n\r\nJ...     4.2
#
#              Company Name       Location  Headquarters
# index
# 0      Healthfirst\r\n3.1   New York, NY  New York, NY  \
# 1          ManTech\r\n4.2  Chantilly, VA   Herndon, VA
#
#                           Size  Founded       Type of ownership
# index
# 0       1001 to 5000 employees     1993  Nonprofit Organization  \
# 1      5001 to 10000 employees     1968        Company - Public
#
#                      Industry             Sector                   Revenue
# index
# 0          Insurance Carriers          Insurance  Unknown / Non-Applicable  \
# 1      Research & Development  Business Services    $1 to $2 billion (USD)
#
#                                    Competitors
# index
# 0      EmblemHealth, UnitedHealth Group, Aetna
# 1                                           -1

# %%
# Get Information needed to Clean the Table

# %%
column_info = info_about_columns(dataFrame, data_science_descriptions=None)
column_info
# Out:
#                   DataType  # of Categories  categories/sample ratio
# Job Title           object              172                     26.0  \
# Salary Estimate     object               30                      4.0
# Job Description     object              489                     73.0
# Rating             float64               32                      5.0
# Company Name        object              432                     64.0
# Location            object              207                     31.0
# Headquarters        object              229                     34.0
# Size                object                9                      1.0
# Founded              int64              103                     15.0
# Type of ownership   object               13                      2.0
# Industry            object               58                      9.0
# Sector              object               23                      3.0
# Revenue             object               14                      2.0
# Competitors         object              108                     16.0
#
#                    missing values  missing values %
# Job Title                       0               0.0
# Salary Estimate                 0               0.0
# Job Description                 0               0.0
# Rating                          0               0.0
# Company Name                    0               0.0
# Location                        0               0.0
# Headquarters                    0               0.0
# Size                            0               0.0
# Founded                         0               0.0
# Type of ownership               0               0.0
# Industry                        0               0.0
# Sector                          0               0.0
# Revenue                         0               0.0
# Competitors                     0               0.0

# %%
pd.set_option('display.max_colwidth', None)
show_examples_of_data(dataFrame, data_information=column_info,category_cutoff=30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 pd.set_option('display.max_colwidth', None)
# ----> 2 show_examples_of_data(dataFrame, data_information=column_info,category_cutoff=30)
#
# File /var/folders/76/jsv807xd2sx3dxgc92jffhw00000gn/T/ipykernel_96500/954645561.py:43, in show_examples_of_data(dataframe, data_information, category_cutoff)
#      40      data_dictionary.loc[len(data_dictionary.index)] = row_data
#      42      last_column = data_dictionary.columns[-1]
# ---> 43      data_dictionary[last_column] = data_dictionary[last_column].apply( lambda x : x.ljust(20))
#      45 return data_dictionary
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:4631, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4521 def apply(
#    4522     self,
#    4523     func: AggFuncType,
#    (...)
#    4526     **kwargs,
#    4527 ) -> DataFrame | Series:
#    4528     """
#    4529     Invoke function on values of Series.
#    4530
#    (...)
#    4629     dtype: float64
#    4630     """
# -> 4631     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# File /var/folders/76/jsv807xd2sx3dxgc92jffhw00000gn/T/ipykernel_96500/954645561.py:43, in show_examples_of_data.<locals>.<lambda>(x)
#      40      data_dictionary.loc[len(data_dictionary.index)] = row_data
#      42      last_column = data_dictionary.columns[-1]
# ---> 43      data_dictionary[last_column] = data_dictionary[last_column].apply( lambda x : x.ljust(20))
#      45 return data_dictionary
#
# AttributeError: 'int' object has no attribute 'ljust'
