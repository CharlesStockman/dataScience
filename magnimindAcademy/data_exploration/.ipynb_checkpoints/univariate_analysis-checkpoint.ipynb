# %% [markdown]
# In this assignment, you'll continue working with the U.S. Education Dataset from Kaggle. The data gives detailed, state-level information on the several facets of the state of education on an annual basis. To learn more about the data and the column descriptions, you can view the Kaggle link above.
#
# Don't forget to apply the most suitable missing-value-filling techniques you applied in the previous checkpoint to the data. You're supposed to provide your answers to the following questions (1-4) after you handle the missing values.
#
# To complete this assignment, submit a link to a Jupyter Notebook containing your solutions to the following tasks:
#
# Answer the following questions as you work through this assignment, and then submit a link to your Notebook.
#
# Derive the descriptive statistics of the data and discuss the points you find remarkable.
#
# Choose a state (such as California) and draw a line graph of its total revenues and total expenditures over the years. How do these two variables evolve during these years? Try to explain the peaks and troughs with some state-wise news and information around those dates.
#
# In your chosen state, in which of the lessons are the students more successful—math or reading?
#
# What are the distributions of the math and reading scores in the sample?
# Now, look again at the original dataset (before you filled in the missing values). Notice there are too many missing values for math and reading scores. Fill out the missing values using mean, median, and linear interpolation. Then, compare the effects of these techniques on the distributions of the score variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data file and make sure that ther e are no missing values
data_frame_1 = pd.read_csv("states_all_clean.csv")
print("The number of missing values is ", data_frame_1.isna().sum().sum())
# Out:
# The number of missing values is  0

# %%
data_frame_1.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR    ENROLL  TOTAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992  649933.5      2678885.0
# 1      1992_ALASKA      ALASKA  1992  649933.5      1049591.0
# 2     1992_ARIZONA     ARIZONA  1992  649933.5      3258079.0
# 3    1992_ARKANSAS    ARKANSAS  1992  649933.5      1711959.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992  649933.5     26260025.0
#
#    FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0         304177.0      1659028.0       715680.0          2653798.0
# 1         106780.0       720711.0       222100.0           972488.0
# 2         297888.0      1369815.0      1590376.0          3401580.0
# 3         178571.0       958785.0       574603.0          1743022.0
# 4        2072470.0     16546514.0      7641041.0         27138832.0
#
#    INSTRUCTION_EXPENDITURE  ...  GRADES_4_G  GRADES_8_G  GRADES_12_G  \
# 0                1481703.0  ...     57948.0     58025.0      41167.0
# 1                 498362.0  ...      9748.0      8789.0       6714.0
# 2                1435908.0  ...     55433.0     49081.0      37410.0
# 3                 964323.0  ...     34632.0     36011.0      27651.0
# 4               14358922.0  ...    418418.0    363296.0     270675.0
#
#    GRADES_1_8_G  GRADES_9_12_G  GRADES_ALL_G  AVG_MATH_4_SCORE  \
# 0      405111.5       186919.0      731634.0             208.0
# 1      405111.5       186919.0      122487.0             238.0
# 2      405111.5       186919.0      673477.0             215.0
# 3      405111.5       186919.0      441490.0             210.0
# 4      405111.5       186919.0     5254844.0             208.0
#
#    AVG_MATH_8_SCORE  AVG_READING_4_SCORE  AVG_READING_8_SCORE
# 0             252.0                207.0                265.0
# 1             280.5                220.0                265.0
# 2             265.0                209.0                265.0
# 3             256.0                211.0                265.0
# 4             261.0                202.0                265.0
#
# [5 rows x 25 columns]

# %%
data_frame_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PRIMARY_KEY                   1715 non-null   object
#  1   STATE                         1715 non-null   object
#  2   YEAR                          1715 non-null   int64
#  3   ENROLL                        1715 non-null   float64
#  4   TOTAL_REVENUE                 1715 non-null   float64
#  5   FEDERAL_REVENUE               1715 non-null   float64
#  6   STATE_REVENUE                 1715 non-null   float64
#  7   LOCAL_REVENUE                 1715 non-null   float64
#  8   TOTAL_EXPENDITURE             1715 non-null   float64
#  9   INSTRUCTION_EXPENDITURE       1715 non-null   float64
#  10  SUPPORT_SERVICES_EXPENDITURE  1715 non-null   float64
#  11  OTHER_EXPENDITURE             1715 non-null   float64
#  12  CAPITAL_OUTLAY_EXPENDITURE    1715 non-null   float64
#  13  GRADES_PK_G                   1715 non-null   float64
#  14  GRADES_KG_G                   1715 non-null   float64
#  15  GRADES_4_G                    1715 non-null   float64
#  16  GRADES_8_G                    1715 non-null   float64
#  17  GRADES_12_G                   1715 non-null   float64
#  18  GRADES_1_8_G                  1715 non-null   float64
#  19  GRADES_9_12_G                 1715 non-null   float64
#  20  GRADES_ALL_G                  1715 non-null   float64
#  21  AVG_MATH_4_SCORE              1715 non-null   float64
#  22  AVG_MATH_8_SCORE              1715 non-null   float64
#  23  AVG_READING_4_SCORE           1715 non-null   float64
#  24  AVG_READING_8_SCORE           1715 non-null   float64
# dtypes: float64(22), int64(1), object(2)
# memory usage: 335.1+ KB

# %% [markdown]
# Derive the descriptive statistics
#
# of the data and discuss the points you find remarkable.

# %%
data_frame_1.describe(include='all')
# Out:
#          PRIMARY_KEY    STATE         YEAR        ENROLL  TOTAL_REVENUE  \
# count           1715     1715  1715.000000  1.715000e+03   1.715000e+03
# unique          1715       53          NaN           NaN            NaN
# top     1992_ALABAMA  ALABAMA          NaN           NaN            NaN
# freq               1       33          NaN           NaN            NaN
# mean             NaN      NaN  2002.075219  8.409261e+05   8.071645e+06
# std              NaN      NaN     9.568621  9.089854e+05   1.028917e+07
# min              NaN      NaN  1986.000000  4.386600e+04   4.656500e+05
# 25%              NaN      NaN  1994.000000  4.646880e+05   2.992297e+06
# 50%              NaN      NaN  2002.000000  6.499335e+05   5.085826e+06
# 75%              NaN      NaN  2010.000000  8.694485e+05   8.165744e+06
# max              NaN      NaN  2019.000000  6.307022e+06   8.921726e+07
#
#         FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count      1.715000e+03   1.715000e+03   1.715000e+03       1.715000e+03
# unique              NaN            NaN            NaN                NaN
# top                 NaN            NaN            NaN                NaN
# freq                NaN            NaN            NaN                NaN
# mean       6.743326e+05   3.791186e+06   3.584183e+06       8.189349e+06
# std        1.001591e+06   4.841024e+06   4.816898e+06       1.048349e+07
# min        3.102000e+04   0.000000e+00   2.209300e+04       4.816650e+05
# 25%        2.602770e+05   1.618602e+06   1.162580e+06       3.004448e+06
# 50%        4.035480e+05   2.537754e+06   2.058996e+06       5.242672e+06
# 75%        6.732800e+05   3.837822e+06   3.484108e+06       8.220253e+06
# max        9.990221e+06   5.090457e+07   3.610526e+07       8.532013e+07
#
#         INSTRUCTION_EXPENDITURE  ...     GRADES_4_G     GRADES_8_G  \
# count              1.715000e+03  ...    1715.000000    1715.000000
# unique                      NaN  ...            NaN            NaN
# top                         NaN  ...            NaN            NaN
# freq                        NaN  ...            NaN            NaN
# mean               4.226732e+06  ...   68194.730029   67127.643732
# std                5.509629e+06  ...   78117.005891   76178.524321
# min                2.655490e+05  ...    4577.000000    3371.000000
# 25%                1.570157e+06  ...   20486.500000   20518.500000
# 50%                2.658253e+06  ...   49087.000000   47880.000000
# 75%                4.133618e+06  ...   77052.000000   76719.500000
# max                4.396452e+07  ...  493415.000000  500143.000000
#
#           GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  GRADES_ALL_G  \
# count     1715.000000  1.715000e+03   1.715000e+03  1.715000e+03
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean     57500.714286  5.079104e+05   2.463393e+05  9.009913e+05
# std      65911.908766  5.279302e+05   2.653303e+05  1.031617e+06
# min       2572.000000  3.769800e+04   1.353000e+04  6.844900e+04
# 25%      17949.000000  3.158105e+05   1.457900e+05  2.800010e+05
# 50%      39408.000000  4.051115e+05   1.869190e+05  6.458050e+05
# 75%      68023.000000  4.815905e+05   2.528075e+05  1.002840e+06
# max     498403.000000  3.929869e+06   2.013687e+06  6.441557e+06
#
#         AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# count        1715.000000       1715.000000          1715.000000
# unique               NaN               NaN                  NaN
# top                  NaN               NaN                  NaN
# freq                 NaN               NaN                  NaN
# mean          237.448980        279.720991           219.547522
# std             5.384205          6.215863             4.762313
# min           192.000000        231.000000           179.000000
# 25%           238.000000        280.500000           220.000000
# 50%           238.000000        280.500000           220.000000
# 75%           238.000000        280.500000           220.000000
# max           253.000000        301.000000           237.000000
#
#         AVG_READING_8_SCORE
# count           1715.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean             264.527697
# std                3.843150
# min              236.000000
# 25%              265.000000
# 50%              265.000000
# 75%              265.000000
# max              280.000000
#
# [11 rows x 25 columns]

# %% [markdown]
# What interest me about the information from the describe is that the
# local expenditure and states have a bigger value than the mean.  The bigger value does not surprise new since the news reports funding problems from the federal, but always from local.

# %% [markdown]
# ## Choose a state (such as California)
#
# and draw a line graph of its total revenues and total expenditures
# over the years. How do these two variables evolve during these
# years? Try to explain the peaks and troughs with some state-wise
# news and information around those dates.

# %%
total_revenue_points = data_frame_1.query( "STATE == 'VIRGINIA'")["TOTAL_REVENUE"]
total_expenditure_points = data_frame_1.query("STATE == 'VIRGINIA'")["TOTAL_EXPENDITURE"]
years=data_frame_1['YEAR'].unique()
plt.plot(years, total_revenue_points, label="Total Revenue")
plt.plot(years, total_expenditure_points, label="Total Expenditure")
plt.title("Total Revenue vs. Total Expenditure")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# Analyssis of Data
#
# 1. We always need QA.  I would have checked, but this week there is a lot of work to completed.  It weird that I get that extra line, but I
# will look at that later.
#
#
# 2. This is an interesting based on this I would definitey do more research to see if Virginaia has a balanced budget.  I am very suprised how close the total revenue is to total expenditure.
#
# 3. Also, any debt that they have incurred from this, I would try to pay off qucikly since it probably very small.

# %% [markdown]
# ##In your chosen state, in which of the lessons
#
# are the students more successful—math or reading?

# %%
data_frame_2 = data_frame_1[["AVG_MATH_4_SCORE","AVG_MATH_8_SCORE", "AVG_READING_4_SCORE", "AVG_READING_8_SCORE"]]
data_frame_2.head()
# Out:
#    AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# 0             208.0             252.0                207.0
# 1             238.0             280.5                220.0
# 2             215.0             265.0                209.0
# 3             210.0             256.0                211.0
# 4             208.0             261.0                202.0
#
#    AVG_READING_8_SCORE
# 0                265.0
# 1                265.0
# 2                265.0
# 3                265.0
# 4                265.0

# %%
data_frame_2.describe()
# Out:
#        AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# count       1715.000000       1715.000000          1715.000000
# mean         237.448980        279.720991           219.547522
# std            5.384205          6.215863             4.762313
# min          192.000000        231.000000           179.000000
# 25%          238.000000        280.500000           220.000000
# 50%          238.000000        280.500000           220.000000
# 75%          238.000000        280.500000           220.000000
# max          253.000000        301.000000           237.000000
#
#        AVG_READING_8_SCORE
# count          1715.000000
# mean            264.527697
# std               3.843150
# min             236.000000
# 25%             265.000000
# 50%             265.000000
# 75%             265.000000
# max             280.000000

# %%
math_score = data_frame_2[["AVG_MATH_4_SCORE", "AVG_MATH_8_SCORE"]].sum().sum()
read_score = data_frame_2[["AVG_READING_4_SCORE", "AVG_READING_8_SCORE"]].sum().sum()
result = "math " if math_score > read_score else "write"
print("The students are better at", result)
# Out:
# The students are better at math

# %% [markdown]
# ## What are the distributions
#
# of the math and reading scores in the sample?

# %%
import numpy.random as rand
import numpy as np

fig, ax = plt.subplots(2,2)
fig.tight_layout()
ax[0][0].set_title("Avg Math 4 Score")
ax[0][1].set_title("Avg Math 8 Score")
ax[1][0].set_title("Avg Reading 4 Score")
ax[1][1].set_title("Avg Reading 8 Score")
fig.suptitle("Showing Central Mean Tendnacy Using Histograms", y=1.09)
plt.subplots_adjust(hspace=.5)
        
ax[0][0].hist(data_frame_2['AVG_MATH_4_SCORE'], bins=10)
ax[0][1].hist(data_frame_2['AVG_MATH_8_SCORE'], bins=10)
ax[1][0].hist(data_frame_2['AVG_READING_4_SCORE'], bins=10)
ax[1][1].hist(data_frame_2['AVG_READING_8_SCORE'], bins=10)
plt.show()

# %% [markdown]
# ## Now, look again at the original dataset
#
# (before you filled in the missing values). Notice there are too many missing values for math and reading scores. Fill out the missing values using mean, median, and linear interpolation. Then, compare the effects of these techniques on the distributions of the score variables.

# %%
data_frame_3 = pd.read_csv('states_all.csv')

# %%
"Number of missing values " + str(data_frame_3.isna().sum().sum())
data_frame_3 = data_frame_3[["AVG_MATH_4_SCORE", "AVG_MATH_8_SCORE", "AVG_READING_4_SCORE", "AVG_READING_8_SCORE"]]
data_frame_3
# Out:
#       AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# 0                208.0             252.0                207.0
# 1                  NaN               NaN                  NaN
# 2                215.0             265.0                209.0
# 3                210.0             256.0                211.0
# 4                208.0             261.0                202.0
# ...                ...               ...                  ...
# 1710             247.0             287.0                224.0
# 1711             240.0             286.0                220.0
# 1712             231.0             272.0                213.0
# 1713             242.0             289.0                220.0
# 1714             246.0             286.0                227.0
#
#       AVG_READING_8_SCORE
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1710                262.0
# 1711                266.0
# 1712                256.0
# 1713                267.0
# 1714                265.0
#
# [1715 rows x 4 columns]

# %%
# fill in missing values 
data_fix_using_missing_mean = data_frame_3.copy()
data_fix_using_missing_mean.fillna(data_frame_4.mean(), inplace=True)
print("Number of missing values " + str(data_fix_using_missing_mean.isna().sum().sum()))
data_fix_using_missing_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 # fill in missing values
#       2 data_fix_using_missing_mean = data_frame_3.copy()
# ----> 3 data_fix_using_missing_mean.fillna(data_frame_4.mean(), inplace=True)
#       4 print("Number of missing values " + str(data_fix_using_missing_mean.isna().sum().sum()))
#       5 data_fix_using_missing_mean
#
# NameError: name 'data_frame_4' is not defined

# %%
# data fill in missing values using media
data_fix_using_median = data_frame_3.copy()
data_fix_using_median.fillna(data_fix_using_median.median(), inplace=True)
print("Number of missing values " + str(data_frame_5.isna().sum().sum()))
data_fix_using_median

# %%
data_fix_using_interpolate = data_frame_3.copy()
data_fix_using_interpolate = data_fix_using_interpolate.interpolate(limit_direction='both')
"Number of missing values " + str(data_fix_using_interpolate.isna().sum().sum())
data_fix_using_interpolate

# %% [markdown]
# What are the distributions of the math and reading scores in the sample? Now, look again at the original dataset (before you filled in the missing values). Notice there are too many missing values for math and reading scores. Fill out the missing values using mean, median, and linear interpolation. Then, compare the effects of these techniques on the distributions of the score variables.
#
# Based on the internet article:https://leportella.com/missing-data/
#
# If the pattern is know interpolation is the best, and if not then mean and the median is the best, but I would median if the data was skewed.
